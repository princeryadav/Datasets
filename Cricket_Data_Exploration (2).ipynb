# %%
# Get dataset from githubs and unzip it.
# !wget https://github.com/princeryadav/Datasets/raw/refs/heads/master/cricket_data.zip -O cricket_data.zip

# !unzip cricket_data.zip -d ./sample_data/
#!unzip cricket_data.zip

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns',None)

# %%
players = pd.read_csv("/content/sample_data/cricket_data.csv", na_values=['-'])
players.shape
# Out:
# /tmp/ipython-input-1076191994.py:1: DtypeWarning: Columns (0,9,16,105,111,112,131,144,145,149,150,151,157,158,162,163,164) have mixed types. Specify dtype option on import or set low_memory=False.
#   players = pd.read_csv("/content/sample_data/cricket_data.csv", na_values=['-'])
# (90309, 181)

# %%
players.head(10)
# Out:
#         ID              NAME  COUNTRY                       Full name  \
# 0     8772      Henry Arkell  England        Henry John Denham Arkell
# 1   532565     Richard Nyren  England                   Richard Nyren
# 2    16856  Sydney Maartensz  England  Sydney Gratien Adair Maartensz
# 3    16715      Brian Lander  England            Brian Richard Lander
# 4    15989  Derek Kenderdine  England        Derek Charles Kenderdine
# 5    16166  Rupert Kitzinger  England        Rupert Charles Kitzinger
# 6  1151914      Megan Lovick  England                    Megan Lovick
# 7   515901       Sophie Luff  England             Sophie Natasha Luff
# 8    17673      Derek Morgan  England            Derek Clifton Morgan
# 9  1152184    Molly Rossiter  England         Molly Beatrice Rossiter
#
#                                              Born  \
# 0           \nJune 26, 1898, Edmonton, Middlesex
# 1              \nApril 25, 1734, Eartham, Sussex
# 2              \nApril 14, 1882, Colombo, Ceylon
# 3  \nJanuary 9, 1942, Bishop Auckland, Co Durham
# 4          \nOctober 28, 1897, Chislehurst, Kent
# 5             \nMarch 24, 1979, Chertsey, Surrey
# 6                                \nJuly 17, 1999
# 7          \nDecember 6, 1993, Taunton, Somerset
# 8   \nFebruary 26, 1929, Muswell Hill, Middlesex
# 9                             \nJanuary 21, 2003
#
#                                                 Died        Current age  \
# 0   March 12, 1982, Oxford (aged 83 years 259 days)                 NaN
# 1  April 25, 1797, Lee or Leigh, Kent (aged 63 ye...                NaN
# 2  September 10, 1967, Pyrford, Woking, Surrey (a...                NaN
# 3                                                NaN   77 years 73 days
# 4  August 28, 1947, Cambridge (aged 49 years 304 ...                NaN
# 5                                                NaN  39 years 364 days
# 6                                                NaN  19 years 249 days
# 7                                                NaN  25 years 107 days
# 8                                                NaN   90 years 25 days
# 9                                                NaN   16 years 61 days
#
#                                          Major teams  \
# 0                                   Northamptonshire
# 1                                       Hampshire XI
# 2                                          Hampshire
# 3                      ['Durham,', 'Minor Counties']
# 4                                         Royal Navy
# 5             ['Dorset,', 'Marylebone Cricket Club']
# 6                                 Charlbury Women CC
# 7  ['Emeralds,', 'England Academy Women,', 'Engla...
# 8                                         Derbyshire
# 9  ['Leicestershire Women,', 'Sileby Town Ladies ...
#
#                                            Education        Height  Nickname  \
# 0                                                NaN           NaN       NaN
# 1                                                NaN           NaN       NaN
# 2                                                NaN           NaN       NaN
# 3                                                NaN           NaN       NaN
# 4                                                NaN           NaN       NaN
# 5  Royal Grammar School, Guildford and Durham Uni...  \n6 ft 8 in        NaN
# 6                                                NaN           NaN       NaN
# 7                                                NaN           NaN       NaN
# 8                                                NaN           NaN       NaN
# 9                                                NaN           NaN       NaN
#
#   Playing role   Batting style               Bowling style  \
# 0          NaN  Right-hand bat                         NaN
# 1          NaN   Left-hand bat  Left-arm bowler (underarm)
# 2          NaN  Right-hand bat                         NaN
# 3          NaN  Right-hand bat            Right-arm medium
# 4          NaN  Right-hand bat       Right-arm medium-fast
# 5          NaN  Right-hand bat       Right-arm medium-fast
# 6          NaN  Right-hand bat            Right-arm medium
# 7          NaN  Right-hand bat            Right-arm medium
# 8          NaN  Right-hand bat       Right-arm fast-medium
# 9          NaN  Right-hand bat            Right-arm medium
#
#                   Other Relation In a nutshell  \
# 0                   NaN      NaN           NaN
# 1                   NaN      NaN           NaN
# 2                   NaN      NaN           NaN
# 3                   NaN      NaN           NaN
# 4                   NaN      NaN           NaN
# 5  Coach, Administrator  Wife -            NaN
# 6                   NaN      NaN           NaN
# 7                   NaN      NaN           NaN
# 8                   NaN      NaN           NaN
# 9                   NaN      NaN           NaN
#
#                                          DESCRIPTION AWARDS  \
# 0                                                 []     []
# 1                                                 []     []
# 2                                                 []     []
# 3                                                 []     []
# 4                                                 []     []
# 5  ['\nRupes is a giant of a man at 6\'8" tall. H...     []
# 6  ["\nLovick's batting style is fairly conservat...     []
# 7  ['\nA tough, hard-working top-order batsman, S...     []
# 8                                                 []     []
# 9  ['\nA patient opener who likes to bats long, R...     []
#
#    BATTING_Tests_Mat  BATTING_Tests_Inns  BATTING_Tests_NO  \
# 0                NaN                 NaN               NaN
# 1                NaN                 NaN               NaN
# 2                NaN                 NaN               NaN
# 3                NaN                 NaN               NaN
# 4                NaN                 NaN               NaN
# 5                NaN                 NaN               NaN
# 6                NaN                 NaN               NaN
# 7                NaN                 NaN               NaN
# 8                NaN                 NaN               NaN
# 9                NaN                 NaN               NaN
#
#    BATTING_Tests_Runs BATTING_Tests_HS  BATTING_Tests_Ave  BATTING_Tests_BF  \
# 0                 NaN              NaN                NaN               NaN
# 1                 NaN              NaN                NaN               NaN
# 2                 NaN              NaN                NaN               NaN
# 3                 NaN              NaN                NaN               NaN
# 4                 NaN              NaN                NaN               NaN
# 5                 NaN              NaN                NaN               NaN
# 6                 NaN              NaN                NaN               NaN
# 7                 NaN              NaN                NaN               NaN
# 8                 NaN              NaN                NaN               NaN
# 9                 NaN              NaN                NaN               NaN
#
#    BATTING_Tests_SR  BATTING_Tests_100  BATTING_Tests_50  BATTING_Tests_4s  \
# 0               NaN                NaN               NaN               NaN
# 1               NaN                NaN               NaN               NaN
# 2               NaN                NaN               NaN               NaN
# 3               NaN                NaN               NaN               NaN
# 4               NaN                NaN               NaN               NaN
# 5               NaN                NaN               NaN               NaN
# 6               NaN                NaN               NaN               NaN
# 7               NaN                NaN               NaN               NaN
# 8               NaN                NaN               NaN               NaN
# 9               NaN                NaN               NaN               NaN
#
#    BATTING_Tests_6s  BATTING_Tests_Ct  BATTING_Tests_St  BATTING_ODIs_Mat  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN               NaN               NaN
# 2               NaN               NaN               NaN               NaN
# 3               NaN               NaN               NaN               NaN
# 4               NaN               NaN               NaN               NaN
# 5               NaN               NaN               NaN               NaN
# 6               NaN               NaN               NaN               NaN
# 7               NaN               NaN               NaN               NaN
# 8               NaN               NaN               NaN               NaN
# 9               NaN               NaN               NaN               NaN
#
#    BATTING_ODIs_Inns  BATTING_ODIs_NO  BATTING_ODIs_Runs BATTING_ODIs_HS  \
# 0                NaN              NaN                NaN             NaN
# 1                NaN              NaN                NaN             NaN
# 2                NaN              NaN                NaN             NaN
# 3                NaN              NaN                NaN             NaN
# 4                NaN              NaN                NaN             NaN
# 5                NaN              NaN                NaN             NaN
# 6                NaN              NaN                NaN             NaN
# 7                NaN              NaN                NaN             NaN
# 8                NaN              NaN                NaN             NaN
# 9                NaN              NaN                NaN             NaN
#
#    BATTING_ODIs_Ave  BATTING_ODIs_BF  BATTING_ODIs_SR  BATTING_ODIs_100  \
# 0               NaN              NaN              NaN               NaN
# 1               NaN              NaN              NaN               NaN
# 2               NaN              NaN              NaN               NaN
# 3               NaN              NaN              NaN               NaN
# 4               NaN              NaN              NaN               NaN
# 5               NaN              NaN              NaN               NaN
# 6               NaN              NaN              NaN               NaN
# 7               NaN              NaN              NaN               NaN
# 8               NaN              NaN              NaN               NaN
# 9               NaN              NaN              NaN               NaN
#
#    BATTING_ODIs_50  BATTING_ODIs_4s  BATTING_ODIs_6s  BATTING_ODIs_Ct  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
# 5              NaN              NaN              NaN              NaN
# 6              NaN              NaN              NaN              NaN
# 7              NaN              NaN              NaN              NaN
# 8              NaN              NaN              NaN              NaN
# 9              NaN              NaN              NaN              NaN
#
#    BATTING_ODIs_St  BATTING_T20Is_Mat  BATTING_T20Is_Inns  BATTING_T20Is_NO  \
# 0              NaN                NaN                 NaN               NaN
# 1              NaN                NaN                 NaN               NaN
# 2              NaN                NaN                 NaN               NaN
# 3              NaN                NaN                 NaN               NaN
# 4              NaN                NaN                 NaN               NaN
# 5              NaN                NaN                 NaN               NaN
# 6              NaN                NaN                 NaN               NaN
# 7              NaN                NaN                 NaN               NaN
# 8              NaN                NaN                 NaN               NaN
# 9              NaN                NaN                 NaN               NaN
#
#    BATTING_T20Is_Runs BATTING_T20Is_HS  BATTING_T20Is_Ave  BATTING_T20Is_BF  \
# 0                 NaN              NaN                NaN               NaN
# 1                 NaN              NaN                NaN               NaN
# 2                 NaN              NaN                NaN               NaN
# 3                 NaN              NaN                NaN               NaN
# 4                 NaN              NaN                NaN               NaN
# 5                 NaN              NaN                NaN               NaN
# 6                 NaN              NaN                NaN               NaN
# 7                 NaN              NaN                NaN               NaN
# 8                 NaN              NaN                NaN               NaN
# 9                 NaN              NaN                NaN               NaN
#
#    BATTING_T20Is_SR  BATTING_T20Is_100  BATTING_T20Is_50  BATTING_T20Is_4s  \
# 0               NaN                NaN               NaN               NaN
# 1               NaN                NaN               NaN               NaN
# 2               NaN                NaN               NaN               NaN
# 3               NaN                NaN               NaN               NaN
# 4               NaN                NaN               NaN               NaN
# 5               NaN                NaN               NaN               NaN
# 6               NaN                NaN               NaN               NaN
# 7               NaN                NaN               NaN               NaN
# 8               NaN                NaN               NaN               NaN
# 9               NaN                NaN               NaN               NaN
#
#    BATTING_T20Is_6s  BATTING_T20Is_Ct  BATTING_T20Is_St  \
# 0               NaN               NaN               NaN
# 1               NaN               NaN               NaN
# 2               NaN               NaN               NaN
# 3               NaN               NaN               NaN
# 4               NaN               NaN               NaN
# 5               NaN               NaN               NaN
# 6               NaN               NaN               NaN
# 7               NaN               NaN               NaN
# 8               NaN               NaN               NaN
# 9               NaN               NaN               NaN
#
#    BATTING_First-class_Mat  BATTING_First-class_Inns  BATTING_First-class_NO  \
# 0                      2.0                       2.0                     0.0
# 1                     49.0                      90.0                    11.0
# 2                     12.0                      17.0                     2.0
# 3                      NaN                       NaN                     NaN
# 4                      2.0                       4.0                     1.0
# 5                      NaN                       NaN                     NaN
# 6                      NaN                       NaN                     NaN
# 7                      NaN                       NaN                     NaN
# 8                    556.0                     882.0                   146.0
# 9                      NaN                       NaN                     NaN
#
#    BATTING_First-class_Runs BATTING_First-class_HS  BATTING_First-class_Ave  \
# 0                      11.0                      6                     5.50
# 1                    1026.0                     97                    12.98
# 2                     283.0                     60                    18.86
# 3                       NaN                    NaN                      NaN
# 4                       7.0                      6                     2.33
# 5                       NaN                    NaN                      NaN
# 6                       NaN                    NaN                      NaN
# 7                       NaN                    NaN                      NaN
# 8                   18356.0                    147                    24.94
# 9                       NaN                    NaN                      NaN
#
#    BATTING_First-class_BF  BATTING_First-class_SR  BATTING_First-class_100  \
# 0                     NaN                     NaN                      0.0
# 1                     NaN                     NaN                      0.0
# 2                     NaN                     NaN                      0.0
# 3                     NaN                     NaN                      NaN
# 4                     NaN                     NaN                      0.0
# 5                     NaN                     NaN                      NaN
# 6                     NaN                     NaN                      NaN
# 7                     NaN                     NaN                      NaN
# 8                     NaN                     NaN                      9.0
# 9                     NaN                     NaN                      NaN
#
#    BATTING_First-class_50  BATTING_First-class_4s  BATTING_First-class_6s  \
# 0                     0.0                     NaN                     NaN
# 1                     2.0                     NaN                     NaN
# 2                     1.0                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     0.0                     NaN                     NaN
# 5                     NaN                     NaN                     NaN
# 6                     NaN                     NaN                     NaN
# 7                     NaN                     NaN                     NaN
# 8                    83.0                     NaN                     NaN
# 9                     NaN                     NaN                     NaN
#
#    BATTING_First-class_Ct  BATTING_First-class_St  BATTING_List A_Mat  \
# 0                     0.0                     0.0                 NaN
# 1                    24.0                     0.0                 NaN
# 2                    21.0                     4.0                 NaN
# 3                     NaN                     NaN                26.0
# 4                     1.0                     0.0                 NaN
# 5                     NaN                     NaN                 NaN
# 6                     NaN                     NaN                 NaN
# 7                     NaN                     NaN                 NaN
# 8                   573.0                     0.0                27.0
# 9                     NaN                     NaN                 NaN
#
#    BATTING_List A_Inns  BATTING_List A_NO  BATTING_List A_Runs  \
# 0                  NaN                NaN                  NaN
# 1                  NaN                NaN                  NaN
# 2                  NaN                NaN                  NaN
# 3                 21.0                3.0                122.0
# 4                  NaN                NaN                  NaN
# 5                  NaN                NaN                  NaN
# 6                  NaN                NaN                  NaN
# 7                  NaN                NaN                  NaN
# 8                 25.0                3.0                360.0
# 9                  NaN                NaN                  NaN
#
#   BATTING_List A_HS  BATTING_List A_Ave  BATTING_List A_BF  BATTING_List A_SR  \
# 0               NaN                 NaN                NaN                NaN
# 1               NaN                 NaN                NaN                NaN
# 2               NaN                 NaN                NaN                NaN
# 3                28                6.77                NaN                NaN
# 4               NaN                 NaN                NaN                NaN
# 5               NaN                 NaN                NaN                NaN
# 6               NaN                 NaN                NaN                NaN
# 7               NaN                 NaN                NaN                NaN
# 8               59*               16.36                NaN                NaN
# 9               NaN                 NaN                NaN                NaN
#
#    BATTING_List A_100  BATTING_List A_50  BATTING_List A_4s  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 0.0                0.0                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 0.0                1.0                NaN
# 9                 NaN                NaN                NaN
#
#    BATTING_List A_6s  BATTING_List A_Ct  BATTING_List A_St  BATTING_T20s_Mat  \
# 0                NaN                NaN                NaN               NaN
# 1                NaN                NaN                NaN               NaN
# 2                NaN                NaN                NaN               NaN
# 3                NaN                2.0                0.0               NaN
# 4                NaN                NaN                NaN               NaN
# 5                NaN                NaN                NaN               NaN
# 6                NaN                NaN                NaN               NaN
# 7                NaN                NaN                NaN               NaN
# 8                NaN               11.0                0.0               NaN
# 9                NaN                NaN                NaN               NaN
#
#    BATTING_T20s_Inns  BATTING_T20s_NO  BATTING_T20s_Runs BATTING_T20s_HS  \
# 0                NaN              NaN                NaN             NaN
# 1                NaN              NaN                NaN             NaN
# 2                NaN              NaN                NaN             NaN
# 3                NaN              NaN                NaN             NaN
# 4                NaN              NaN                NaN             NaN
# 5                NaN              NaN                NaN             NaN
# 6                NaN              NaN                NaN             NaN
# 7                NaN              NaN                NaN             NaN
# 8                NaN              NaN                NaN             NaN
# 9                NaN              NaN                NaN             NaN
#
#    BATTING_T20s_Ave  BATTING_T20s_BF  BATTING_T20s_SR  BATTING_T20s_100  \
# 0               NaN              NaN              NaN               NaN
# 1               NaN              NaN              NaN               NaN
# 2               NaN              NaN              NaN               NaN
# 3               NaN              NaN              NaN               NaN
# 4               NaN              NaN              NaN               NaN
# 5               NaN              NaN              NaN               NaN
# 6               NaN              NaN              NaN               NaN
# 7               NaN              NaN              NaN               NaN
# 8               NaN              NaN              NaN               NaN
# 9               NaN              NaN              NaN               NaN
#
#    BATTING_T20s_50  BATTING_T20s_4s  BATTING_T20s_6s  BATTING_T20s_Ct  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
# 5              NaN              NaN              NaN              NaN
# 6              NaN              NaN              NaN              NaN
# 7              NaN              NaN              NaN              NaN
# 8              NaN              NaN              NaN              NaN
# 9              NaN              NaN              NaN              NaN
#
#    BATTING_T20s_St  BOWLING_Tests_Mat  BOWLING_Tests_Inns BOWLING_Tests_Balls  \
# 0              NaN                NaN                 NaN                 NaN
# 1              NaN                NaN                 NaN                 NaN
# 2              NaN                NaN                 NaN                 NaN
# 3              NaN                NaN                 NaN                 NaN
# 4              NaN                NaN                 NaN                 NaN
# 5              NaN                NaN                 NaN                 NaN
# 6              NaN                NaN                 NaN                 NaN
# 7              NaN                NaN                 NaN                 NaN
# 8              NaN                NaN                 NaN                 NaN
# 9              NaN                NaN                 NaN                 NaN
#
#    BOWLING_Tests_Runs  BOWLING_Tests_Wkts BOWLING_Tests_BBI BOWLING_Tests_BBM  \
# 0                 NaN                 NaN               NaN               NaN
# 1                 NaN                 NaN               NaN               NaN
# 2                 NaN                 NaN               NaN               NaN
# 3                 NaN                 NaN               NaN               NaN
# 4                 NaN                 NaN               NaN               NaN
# 5                 NaN                 NaN               NaN               NaN
# 6                 NaN                 NaN               NaN               NaN
# 7                 NaN                 NaN               NaN               NaN
# 8                 NaN                 NaN               NaN               NaN
# 9                 NaN                 NaN               NaN               NaN
#
#    BOWLING_Tests_Ave BOWLING_Tests_Econ BOWLING_Tests_SR  BOWLING_Tests_4w  \
# 0                NaN                NaN              NaN               NaN
# 1                NaN                NaN              NaN               NaN
# 2                NaN                NaN              NaN               NaN
# 3                NaN                NaN              NaN               NaN
# 4                NaN                NaN              NaN               NaN
# 5                NaN                NaN              NaN               NaN
# 6                NaN                NaN              NaN               NaN
# 7                NaN                NaN              NaN               NaN
# 8                NaN                NaN              NaN               NaN
# 9                NaN                NaN              NaN               NaN
#
#    BOWLING_Tests_5w  BOWLING_Tests_10  BOWLING_ODIs_Mat  BOWLING_ODIs_Inns  \
# 0               NaN               NaN               NaN                NaN
# 1               NaN               NaN               NaN                NaN
# 2               NaN               NaN               NaN                NaN
# 3               NaN               NaN               NaN                NaN
# 4               NaN               NaN               NaN                NaN
# 5               NaN               NaN               NaN                NaN
# 6               NaN               NaN               NaN                NaN
# 7               NaN               NaN               NaN                NaN
# 8               NaN               NaN               NaN                NaN
# 9               NaN               NaN               NaN                NaN
#
#    BOWLING_ODIs_Balls  BOWLING_ODIs_Runs  BOWLING_ODIs_Wkts BOWLING_ODIs_BBI  \
# 0                 NaN                NaN                NaN              NaN
# 1                 NaN                NaN                NaN              NaN
# 2                 NaN                NaN                NaN              NaN
# 3                 NaN                NaN                NaN              NaN
# 4                 NaN                NaN                NaN              NaN
# 5                 NaN                NaN                NaN              NaN
# 6                 NaN                NaN                NaN              NaN
# 7                 NaN                NaN                NaN              NaN
# 8                 NaN                NaN                NaN              NaN
# 9                 NaN                NaN                NaN              NaN
#
#   BOWLING_ODIs_BBM  BOWLING_ODIs_Ave  BOWLING_ODIs_Econ  BOWLING_ODIs_SR  \
# 0              NaN               NaN                NaN              NaN
# 1              NaN               NaN                NaN              NaN
# 2              NaN               NaN                NaN              NaN
# 3              NaN               NaN                NaN              NaN
# 4              NaN               NaN                NaN              NaN
# 5              NaN               NaN                NaN              NaN
# 6              NaN               NaN                NaN              NaN
# 7              NaN               NaN                NaN              NaN
# 8              NaN               NaN                NaN              NaN
# 9              NaN               NaN                NaN              NaN
#
#    BOWLING_ODIs_4w  BOWLING_ODIs_5w  BOWLING_ODIs_10  BOWLING_T20Is_Mat  \
# 0              NaN              NaN              NaN                NaN
# 1              NaN              NaN              NaN                NaN
# 2              NaN              NaN              NaN                NaN
# 3              NaN              NaN              NaN                NaN
# 4              NaN              NaN              NaN                NaN
# 5              NaN              NaN              NaN                NaN
# 6              NaN              NaN              NaN                NaN
# 7              NaN              NaN              NaN                NaN
# 8              NaN              NaN              NaN                NaN
# 9              NaN              NaN              NaN                NaN
#
#    BOWLING_T20Is_Inns BOWLING_T20Is_Balls  BOWLING_T20Is_Runs  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
# 5                 NaN                 NaN                 NaN
# 6                 NaN                 NaN                 NaN
# 7                 NaN                 NaN                 NaN
# 8                 NaN                 NaN                 NaN
# 9                 NaN                 NaN                 NaN
#
#    BOWLING_T20Is_Wkts BOWLING_T20Is_BBI BOWLING_T20Is_BBM  BOWLING_T20Is_Ave  \
# 0                 NaN               NaN               NaN                NaN
# 1                 NaN               NaN               NaN                NaN
# 2                 NaN               NaN               NaN                NaN
# 3                 NaN               NaN               NaN                NaN
# 4                 NaN               NaN               NaN                NaN
# 5                 NaN               NaN               NaN                NaN
# 6                 NaN               NaN               NaN                NaN
# 7                 NaN               NaN               NaN                NaN
# 8                 NaN               NaN               NaN                NaN
# 9                 NaN               NaN               NaN                NaN
#
#    BOWLING_T20Is_Econ  BOWLING_T20Is_SR  BOWLING_T20Is_4w  BOWLING_T20Is_5w  \
# 0                 NaN               NaN               NaN               NaN
# 1                 NaN               NaN               NaN               NaN
# 2                 NaN               NaN               NaN               NaN
# 3                 NaN               NaN               NaN               NaN
# 4                 NaN               NaN               NaN               NaN
# 5                 NaN               NaN               NaN               NaN
# 6                 NaN               NaN               NaN               NaN
# 7                 NaN               NaN               NaN               NaN
# 8                 NaN               NaN               NaN               NaN
# 9                 NaN               NaN               NaN               NaN
#
#    BOWLING_T20Is_10  BOWLING_First-class_Mat  BOWLING_First-class_Inns  \
# 0               NaN                      2.0                       NaN
# 1               NaN                     49.0                      57.0
# 2               NaN                     12.0                       NaN
# 3               NaN                      NaN                       NaN
# 4               NaN                      2.0                       NaN
# 5               NaN                      NaN                       NaN
# 6               NaN                      NaN                       NaN
# 7               NaN                      NaN                       NaN
# 8               NaN                    556.0                       NaN
# 9               NaN                      NaN                       NaN
#
#   BOWLING_First-class_Balls BOWLING_First-class_Runs  \
# 0                       NaN                      NaN
# 1                        0+                       0+
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       198                      121
# 5                       NaN                      NaN
# 6                       NaN                      NaN
# 7                       NaN                      NaN
# 8                     77255                    31302
# 9                       NaN                      NaN
#
#    BOWLING_First-class_Wkts BOWLING_First-class_BBI BOWLING_First-class_BBM  \
# 0                       NaN                     NaN                     NaN
# 1                     104.0                     5/?                     6/?
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       2.0                  Jan-46                     NaN
# 5                       NaN                     NaN                     NaN
# 6                       NaN                     NaN                     NaN
# 7                       NaN                     NaN                     NaN
# 8                    1248.0                  Jul-33                     NaN
# 9                       NaN                     NaN                     NaN
#
#   BOWLING_First-class_Ave BOWLING_First-class_Econ BOWLING_First-class_SR  \
# 0                     NaN                      NaN                    NaN
# 1                     NaN                      NaN                    NaN
# 2                     NaN                      NaN                    NaN
# 3                     NaN                      NaN                    NaN
# 4                    60.5                     3.66                     99
# 5                     NaN                      NaN                    NaN
# 6                     NaN                      NaN                    NaN
# 7                     NaN                      NaN                    NaN
# 8                   25.08                     2.43                   61.9
# 9                     NaN                      NaN                    NaN
#
#    BOWLING_First-class_4w  BOWLING_First-class_5w  BOWLING_First-class_10  \
# 0                     NaN                     NaN                     NaN
# 1                     7.0                     1.0                     0.0
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     0.0                     0.0
# 5                     NaN                     NaN                     NaN
# 6                     NaN                     NaN                     NaN
# 7                     NaN                     NaN                     NaN
# 8                     NaN                    35.0                     5.0
# 9                     NaN                     NaN                     NaN
#
#    BOWLING_List A_Mat  BOWLING_List A_Inns BOWLING_List A_Balls  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                 NaN                  NaN                  NaN
# 3                26.0                  NaN               1402.0
# 4                 NaN                  NaN                  NaN
# 5                 NaN                  NaN                  NaN
# 6                 NaN                  NaN                  NaN
# 7                 NaN                  NaN                  NaN
# 8                27.0                  NaN                989.0
# 9                 NaN                  NaN                  NaN
#
#   BOWLING_List A_Runs  BOWLING_List A_Wkts BOWLING_List A_BBI  \
# 0                 NaN                  NaN                NaN
# 1                 NaN                  NaN                NaN
# 2                 NaN                  NaN                NaN
# 3               859.0                 25.0             May-15
# 4                 NaN                  NaN                NaN
# 5                 NaN                  NaN                NaN
# 6                 NaN                  NaN                NaN
# 7                 NaN                  NaN                NaN
# 8               600.0                 23.0             Mar-21
# 9                 NaN                  NaN                NaN
#
#   BOWLING_List A_BBM BOWLING_List A_Ave BOWLING_List A_Econ BOWLING_List A_SR  \
# 0                NaN                NaN                 NaN               NaN
# 1                NaN                NaN                 NaN               NaN
# 2                NaN                NaN                 NaN               NaN
# 3             May-15              34.36                3.67              56.0
# 4                NaN                NaN                 NaN               NaN
# 5                NaN                NaN                 NaN               NaN
# 6                NaN                NaN                 NaN               NaN
# 7                NaN                NaN                 NaN               NaN
# 8             Mar-21              26.08                3.64              43.0
# 9                NaN                NaN                 NaN               NaN
#
#    BOWLING_List A_4w  BOWLING_List A_5w  BOWLING_List A_10  BOWLING_T20s_Mat  \
# 0                NaN                NaN                NaN               NaN
# 1                NaN                NaN                NaN               NaN
# 2                NaN                NaN                NaN               NaN
# 3                0.0                1.0                0.0               NaN
# 4                NaN                NaN                NaN               NaN
# 5                NaN                NaN                NaN               NaN
# 6                NaN                NaN                NaN               NaN
# 7                NaN                NaN                NaN               NaN
# 8                0.0                0.0                0.0               NaN
# 9                NaN                NaN                NaN               NaN
#
#    BOWLING_T20s_Inns  BOWLING_T20s_Balls  BOWLING_T20s_Runs  \
# 0                NaN                 NaN                NaN
# 1                NaN                 NaN                NaN
# 2                NaN                 NaN                NaN
# 3                NaN                 NaN                NaN
# 4                NaN                 NaN                NaN
# 5                NaN                 NaN                NaN
# 6                NaN                 NaN                NaN
# 7                NaN                 NaN                NaN
# 8                NaN                 NaN                NaN
# 9                NaN                 NaN                NaN
#
#    BOWLING_T20s_Wkts BOWLING_T20s_BBI BOWLING_T20s_BBM  BOWLING_T20s_Ave  \
# 0                NaN              NaN              NaN               NaN
# 1                NaN              NaN              NaN               NaN
# 2                NaN              NaN              NaN               NaN
# 3                NaN              NaN              NaN               NaN
# 4                NaN              NaN              NaN               NaN
# 5                NaN              NaN              NaN               NaN
# 6                NaN              NaN              NaN               NaN
# 7                NaN              NaN              NaN               NaN
# 8                NaN              NaN              NaN               NaN
# 9                NaN              NaN              NaN               NaN
#
#    BOWLING_T20s_Econ  BOWLING_T20s_SR  BOWLING_T20s_4w  BOWLING_T20s_5w  \
# 0                NaN              NaN              NaN              NaN
# 1                NaN              NaN              NaN              NaN
# 2                NaN              NaN              NaN              NaN
# 3                NaN              NaN              NaN              NaN
# 4                NaN              NaN              NaN              NaN
# 5                NaN              NaN              NaN              NaN
# 6                NaN              NaN              NaN              NaN
# 7                NaN              NaN              NaN              NaN
# 8                NaN              NaN              NaN              NaN
# 9                NaN              NaN              NaN              NaN
#
#    BOWLING_T20s_10
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN

# %%
players.columns.to_list()
# Out:
# ['ID',
#  'NAME',
#  'COUNTRY',
#  'Full name',
#  'Born',
#  'Died',
#  'Current age',
#  'Major teams',
#  'Education',
#  'Height',
#  'Nickname',
#  'Playing role',
#  'Batting style',
#  'Bowling style',
#  'Other',
#  'Relation',
#  'In a nutshell',
#  'DESCRIPTION',
#  'AWARDS',
#  'BATTING_Tests_Mat',
#  'BATTING_Tests_Inns',
#  'BATTING_Tests_NO',
#  'BATTING_Tests_Runs',
#  'BATTING_Tests_HS',
#  'BATTING_Tests_Ave',
#  'BATTING_Tests_BF',
#  'BATTING_Tests_SR',
#  'BATTING_Tests_100',
#  'BATTING_Tests_50',
#  'BATTING_Tests_4s',
#  'BATTING_Tests_6s',
#  'BATTING_Tests_Ct',
#  'BATTING_Tests_St',
#  'BATTING_ODIs_Mat',
#  'BATTING_ODIs_Inns',
#  'BATTING_ODIs_NO',
#  'BATTING_ODIs_Runs',
#  'BATTING_ODIs_HS',
#  'BATTING_ODIs_Ave',
#  'BATTING_ODIs_BF',
#  'BATTING_ODIs_SR',
#  'BATTING_ODIs_100',
#  'BATTING_ODIs_50',
#  'BATTING_ODIs_4s',
#  'BATTING_ODIs_6s',
#  'BATTING_ODIs_Ct',
#  'BATTING_ODIs_St',
#  'BATTING_T20Is_Mat',
#  'BATTING_T20Is_Inns',
#  'BATTING_T20Is_NO',
#  'BATTING_T20Is_Runs',
#  'BATTING_T20Is_HS',
#  'BATTING_T20Is_Ave',
#  'BATTING_T20Is_BF',
#  'BATTING_T20Is_SR',
#  'BATTING_T20Is_100',
#  'BATTING_T20Is_50',
#  'BATTING_T20Is_4s',
#  'BATTING_T20Is_6s',
#  'BATTING_T20Is_Ct',
#  'BATTING_T20Is_St',
#  'BATTING_First-class_Mat',
#  'BATTING_First-class_Inns',
#  'BATTING_First-class_NO',
#  'BATTING_First-class_Runs',
#  'BATTING_First-class_HS',
#  'BATTING_First-class_Ave',
#  'BATTING_First-class_BF',
#  'BATTING_First-class_SR',
#  'BATTING_First-class_100',
#  'BATTING_First-class_50',
#  'BATTING_First-class_4s',
#  'BATTING_First-class_6s',
#  'BATTING_First-class_Ct',
#  'BATTING_First-class_St',
#  'BATTING_List A_Mat',
#  'BATTING_List A_Inns',
#  'BATTING_List A_NO',
#  'BATTING_List A_Runs',
#  'BATTING_List A_HS',
#  'BATTING_List A_Ave',
#  'BATTING_List A_BF',
#  'BATTING_List A_SR',
#  'BATTING_List A_100',
#  'BATTING_List A_50',
#  'BATTING_List A_4s',
#  'BATTING_List A_6s',
#  'BATTING_List A_Ct',
#  'BATTING_List A_St',
#  'BATTING_T20s_Mat',
#  'BATTING_T20s_Inns',
#  'BATTING_T20s_NO',
#  'BATTING_T20s_Runs',
#  'BATTING_T20s_HS',
#  'BATTING_T20s_Ave',
#  'BATTING_T20s_BF',
#  'BATTING_T20s_SR',
#  'BATTING_T20s_100',
#  'BATTING_T20s_50',
#  'BATTING_T20s_4s',
#  'BATTING_T20s_6s',
#  'BATTING_T20s_Ct',
#  'BATTING_T20s_St',
#  'BOWLING_Tests_Mat',
#  'BOWLING_Tests_Inns',
#  'BOWLING_Tests_Balls',
#  'BOWLING_Tests_Runs',
#  'BOWLING_Tests_Wkts',
#  'BOWLING_Tests_BBI',
#  'BOWLING_Tests_BBM',
#  'BOWLING_Tests_Ave',
#  'BOWLING_Tests_Econ',
#  'BOWLING_Tests_SR',
#  'BOWLING_Tests_4w',
#  'BOWLING_Tests_5w',
#  'BOWLING_Tests_10',
#  'BOWLING_ODIs_Mat',
#  'BOWLING_ODIs_Inns',
#  'BOWLING_ODIs_Balls',
#  'BOWLING_ODIs_Runs',
#  'BOWLING_ODIs_Wkts',
#  'BOWLING_ODIs_BBI',
#  'BOWLING_ODIs_BBM',
#  'BOWLING_ODIs_Ave',
#  'BOWLING_ODIs_Econ',
#  'BOWLING_ODIs_SR',
#  'BOWLING_ODIs_4w',
#  'BOWLING_ODIs_5w',
#  'BOWLING_ODIs_10',
#  'BOWLING_T20Is_Mat',
#  'BOWLING_T20Is_Inns',
#  'BOWLING_T20Is_Balls',
#  'BOWLING_T20Is_Runs',
#  'BOWLING_T20Is_Wkts',
#  'BOWLING_T20Is_BBI',
#  'BOWLING_T20Is_BBM',
#  'BOWLING_T20Is_Ave',
#  'BOWLING_T20Is_Econ',
#  'BOWLING_T20Is_SR',
#  'BOWLING_T20Is_4w',
#  'BOWLING_T20Is_5w',
#  'BOWLING_T20Is_10',
#  'BOWLING_First-class_Mat',
#  'BOWLING_First-class_Inns',
#  'BOWLING_First-class_Balls',
#  'BOWLING_First-class_Runs',
#  'BOWLING_First-class_Wkts',
#  'BOWLING_First-class_BBI',
#  'BOWLING_First-class_BBM',
#  'BOWLING_First-class_Ave',
#  'BOWLING_First-class_Econ',
#  'BOWLING_First-class_SR',
#  'BOWLING_First-class_4w',
#  'BOWLING_First-class_5w',
#  'BOWLING_First-class_10',
#  'BOWLING_List A_Mat',
#  'BOWLING_List A_Inns',
#  'BOWLING_List A_Balls',
#  'BOWLING_List A_Runs',
#  'BOWLING_List A_Wkts',
#  'BOWLING_List A_BBI',
#  'BOWLING_List A_BBM',
#  'BOWLING_List A_Ave',
#  'BOWLING_List A_Econ',
#  'BOWLING_List A_SR',
#  'BOWLING_List A_4w',
#  'BOWLING_List A_5w',
#  'BOWLING_List A_10',
#  'BOWLING_T20s_Mat',
#  'BOWLING_T20s_Inns',
#  'BOWLING_T20s_Balls',
#  'BOWLING_T20s_Runs',
#  'BOWLING_T20s_Wkts',
#  'BOWLING_T20s_BBI',
#  'BOWLING_T20s_BBM',
#  'BOWLING_T20s_Ave',
#  'BOWLING_T20s_Econ',
#  'BOWLING_T20s_SR',
#  'BOWLING_T20s_4w',
#  'BOWLING_T20s_5w',
#  'BOWLING_T20s_10']

# %%
players = players[['ID',
 'NAME',
 'COUNTRY',
 'Playing role',
 'Batting style',
 'Bowling style',
 'Other',
 'BATTING_Tests_Mat',
 'BATTING_Tests_Inns',
 'BATTING_Tests_NO',
 'BATTING_Tests_Runs',
 'BATTING_Tests_Ave',
 'BATTING_Tests_SR',
 'BATTING_Tests_100',
 'BATTING_Tests_50',
 'BATTING_ODIs_Mat',
 'BATTING_ODIs_Inns',
 'BATTING_ODIs_NO',
 'BATTING_ODIs_Runs',
 'BATTING_ODIs_Ave',
 'BATTING_ODIs_SR',
 'BATTING_ODIs_100',
 'BATTING_ODIs_50',
 'BATTING_T20Is_Mat',
 'BATTING_T20Is_Inns',
 'BATTING_T20Is_NO',
 'BATTING_T20Is_Runs',
 'BATTING_T20Is_Ave',
 'BATTING_T20Is_SR',
 'BATTING_T20Is_100',
 'BATTING_T20Is_50',
 'BOWLING_Tests_Mat',
 'BOWLING_Tests_Inns',
 'BOWLING_Tests_Balls',
 'BOWLING_Tests_Runs',
 'BOWLING_Tests_Wkts',
 'BOWLING_Tests_Ave',
 'BOWLING_Tests_Econ',
 'BOWLING_Tests_SR',
 'BOWLING_Tests_5w',
 'BOWLING_Tests_10',
 'BOWLING_ODIs_Mat',
 'BOWLING_ODIs_Inns',
 'BOWLING_ODIs_Balls',
 'BOWLING_ODIs_Runs',
 'BOWLING_ODIs_Wkts',
 'BOWLING_ODIs_Ave',
 'BOWLING_ODIs_Econ',
 'BOWLING_ODIs_SR',
 'BOWLING_ODIs_5w',
 'BOWLING_ODIs_10',
 'BOWLING_T20Is_Mat',
 'BOWLING_T20Is_Inns',
 'BOWLING_T20Is_Balls',
 'BOWLING_T20Is_Runs',
 'BOWLING_T20Is_Wkts',
 'BOWLING_T20Is_Ave',
 'BOWLING_T20Is_Econ',
 'BOWLING_T20Is_SR',
 'BOWLING_T20Is_5w',
 'BOWLING_T20Is_10',
]]

# %%
players.head()
# Out:
#        ID              NAME  COUNTRY Playing role   Batting style  \
# 0    8772      Henry Arkell  England          NaN  Right-hand bat
# 1  532565     Richard Nyren  England          NaN   Left-hand bat
# 2   16856  Sydney Maartensz  England          NaN  Right-hand bat
# 3   16715      Brian Lander  England          NaN  Right-hand bat
# 4   15989  Derek Kenderdine  England          NaN  Right-hand bat
#
#                 Bowling style Other  BATTING_Tests_Mat  BATTING_Tests_Inns  \
# 0                         NaN   NaN                NaN                 NaN
# 1  Left-arm bowler (underarm)   NaN                NaN                 NaN
# 2                         NaN   NaN                NaN                 NaN
# 3            Right-arm medium   NaN                NaN                 NaN
# 4       Right-arm medium-fast   NaN                NaN                 NaN
#
#    BATTING_Tests_NO  BATTING_Tests_Runs  BATTING_Tests_Ave  BATTING_Tests_SR  \
# 0               NaN                 NaN                NaN               NaN
# 1               NaN                 NaN                NaN               NaN
# 2               NaN                 NaN                NaN               NaN
# 3               NaN                 NaN                NaN               NaN
# 4               NaN                 NaN                NaN               NaN
#
#    BATTING_Tests_100  BATTING_Tests_50  BATTING_ODIs_Mat  BATTING_ODIs_Inns  \
# 0                NaN               NaN               NaN                NaN
# 1                NaN               NaN               NaN                NaN
# 2                NaN               NaN               NaN                NaN
# 3                NaN               NaN               NaN                NaN
# 4                NaN               NaN               NaN                NaN
#
#    BATTING_ODIs_NO  BATTING_ODIs_Runs  BATTING_ODIs_Ave  BATTING_ODIs_SR  \
# 0              NaN                NaN               NaN              NaN
# 1              NaN                NaN               NaN              NaN
# 2              NaN                NaN               NaN              NaN
# 3              NaN                NaN               NaN              NaN
# 4              NaN                NaN               NaN              NaN
#
#    BATTING_ODIs_100  BATTING_ODIs_50  BATTING_T20Is_Mat  BATTING_T20Is_Inns  \
# 0               NaN              NaN                NaN                 NaN
# 1               NaN              NaN                NaN                 NaN
# 2               NaN              NaN                NaN                 NaN
# 3               NaN              NaN                NaN                 NaN
# 4               NaN              NaN                NaN                 NaN
#
#    BATTING_T20Is_NO  BATTING_T20Is_Runs  BATTING_T20Is_Ave  BATTING_T20Is_SR  \
# 0               NaN                 NaN                NaN               NaN
# 1               NaN                 NaN                NaN               NaN
# 2               NaN                 NaN                NaN               NaN
# 3               NaN                 NaN                NaN               NaN
# 4               NaN                 NaN                NaN               NaN
#
#    BATTING_T20Is_100  BATTING_T20Is_50  BOWLING_Tests_Mat  BOWLING_Tests_Inns  \
# 0                NaN               NaN                NaN                 NaN
# 1                NaN               NaN                NaN                 NaN
# 2                NaN               NaN                NaN                 NaN
# 3                NaN               NaN                NaN                 NaN
# 4                NaN               NaN                NaN                 NaN
#
#   BOWLING_Tests_Balls  BOWLING_Tests_Runs  BOWLING_Tests_Wkts  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    BOWLING_Tests_Ave BOWLING_Tests_Econ BOWLING_Tests_SR  BOWLING_Tests_5w  \
# 0                NaN                NaN              NaN               NaN
# 1                NaN                NaN              NaN               NaN
# 2                NaN                NaN              NaN               NaN
# 3                NaN                NaN              NaN               NaN
# 4                NaN                NaN              NaN               NaN
#
#    BOWLING_Tests_10  BOWLING_ODIs_Mat  BOWLING_ODIs_Inns  BOWLING_ODIs_Balls  \
# 0               NaN               NaN                NaN                 NaN
# 1               NaN               NaN                NaN                 NaN
# 2               NaN               NaN                NaN                 NaN
# 3               NaN               NaN                NaN                 NaN
# 4               NaN               NaN                NaN                 NaN
#
#    BOWLING_ODIs_Runs  BOWLING_ODIs_Wkts  BOWLING_ODIs_Ave  BOWLING_ODIs_Econ  \
# 0                NaN                NaN               NaN                NaN
# 1                NaN                NaN               NaN                NaN
# 2                NaN                NaN               NaN                NaN
# 3                NaN                NaN               NaN                NaN
# 4                NaN                NaN               NaN                NaN
#
#    BOWLING_ODIs_SR  BOWLING_ODIs_5w  BOWLING_ODIs_10  BOWLING_T20Is_Mat  \
# 0              NaN              NaN              NaN                NaN
# 1              NaN              NaN              NaN                NaN
# 2              NaN              NaN              NaN                NaN
# 3              NaN              NaN              NaN                NaN
# 4              NaN              NaN              NaN                NaN
#
#    BOWLING_T20Is_Inns BOWLING_T20Is_Balls  BOWLING_T20Is_Runs  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    BOWLING_T20Is_Wkts  BOWLING_T20Is_Ave  BOWLING_T20Is_Econ  \
# 0                 NaN                NaN                 NaN
# 1                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 3                 NaN                NaN                 NaN
# 4                 NaN                NaN                 NaN
#
#    BOWLING_T20Is_SR  BOWLING_T20Is_5w  BOWLING_T20Is_10
# 0               NaN               NaN               NaN
# 1               NaN               NaN               NaN
# 2               NaN               NaN               NaN
# 3               NaN               NaN               NaN
# 4               NaN               NaN               NaN

# %%
players = players[['ID',
 'NAME',
 'COUNTRY',
 'Playing role',
 'Batting style',
 'Bowling style',
 'BATTING_Tests_Mat',
 'BATTING_Tests_Inns',
 'BATTING_Tests_NO',
 'BATTING_Tests_Runs',
 'BATTING_Tests_Ave',
 'BATTING_Tests_SR',
 'BATTING_Tests_100',
 'BATTING_Tests_50',
 'BOWLING_Tests_Mat',
 'BOWLING_Tests_Inns',
 'BOWLING_Tests_Balls',
 'BOWLING_Tests_Runs',
 'BOWLING_Tests_Wkts',
 'BOWLING_Tests_Ave',
 'BOWLING_Tests_Econ',
 'BOWLING_Tests_SR',
 'BOWLING_Tests_5w',
 'BOWLING_Tests_10',
]]

# %%
players.isna().sum()
# Out:
# ID                         0
# NAME                       2
# COUNTRY                    0
# Playing role           86590
# Batting style          33056
# Bowling style          46224
# BATTING_Tests_Mat      86658
# BATTING_Tests_Inns     86705
# BATTING_Tests_NO       86705
# BATTING_Tests_Runs     86705
# BATTING_Tests_Ave      86801
# BATTING_Tests_SR       88673
# BATTING_Tests_100      86705
# BATTING_Tests_50       86705
# BOWLING_Tests_Mat      86658
# BOWLING_Tests_Inns     87627
# BOWLING_Tests_Balls    87627
# BOWLING_Tests_Runs     87627
# BOWLING_Tests_Wkts     87627
# BOWLING_Tests_Ave      88169
# BOWLING_Tests_Econ     87627
# BOWLING_Tests_SR       88169
# BOWLING_Tests_5w       87627
# BOWLING_Tests_10       87627
# dtype: int64

# %%
players[players['Playing role'].notna()]
# Out:
#             ID               NAME      COUNTRY          Playing role  \
# 12       43860  Zulqarnain Haider     Pakistan  Wicketkeeper batsman
# 41      318615   Zeeshan Siddiqui         Oman               Batsman
# 56     1159659       Kenton Young       Belize          Wicketkeeper
# 69     1107677     Philip Yevugah        Ghana            Allrounder
# 126    1013221         Jamal Vira      Vanuatu  Wicketkeeper batsman
# ...        ...                ...          ...                   ...
# 90263    52969   Ramnaresh Sarwan  West Indies               Batsman
# 90271   314622  Krishmar Santokie  West Indies                Bowler
# 90288    52983     Marlon Samuels  West Indies     Top-order batsman
# 90291   252954      Lennox Samuel  West Indies               Batsman
# 90298   333056      Jason Saddler  West Indies            Allrounder
#
#         Batting style       Bowling style  BATTING_Tests_Mat  \
# 12     Right-hand bat                 NaN                1.0
# 41     Right-hand bat            Legbreak                NaN
# 56      Left-hand bat                 NaN                NaN
# 69     Right-hand bat    Right-arm medium                NaN
# 126    Right-hand bat                 NaN                NaN
# ...               ...                 ...                ...
# 90263  Right-hand bat            Legbreak               87.0
# 90271   Left-hand bat     Left-arm medium                NaN
# 90288  Right-hand bat  Right-arm offbreak               71.0
# 90291  Right-hand bat  Right-arm offbreak                NaN
# 90298  Right-hand bat    Right-arm medium                NaN
#
#        BATTING_Tests_Inns  BATTING_Tests_NO  BATTING_Tests_Runs  \
# 12                    2.0               0.0                88.0
# 41                    NaN               NaN                 NaN
# 56                    NaN               NaN                 NaN
# 69                    NaN               NaN                 NaN
# 126                   NaN               NaN                 NaN
# ...                   ...               ...                 ...
# 90263               154.0               8.0              5842.0
# 90271                 NaN               NaN                 NaN
# 90288               127.0               7.0              3917.0
# 90291                 NaN               NaN                 NaN
# 90298                 NaN               NaN                 NaN
#
#        BATTING_Tests_Ave  BATTING_Tests_SR  BATTING_Tests_100  \
# 12                 44.00             43.78                0.0
# 41                   NaN               NaN                NaN
# 56                   NaN               NaN                NaN
# 69                   NaN               NaN                NaN
# 126                  NaN               NaN                NaN
# ...                  ...               ...                ...
# 90263              40.01             46.79               15.0
# 90271                NaN               NaN                NaN
# 90288              32.64             47.65                7.0
# 90291                NaN               NaN                NaN
# 90298                NaN               NaN                NaN
#
#        BATTING_Tests_50  BOWLING_Tests_Mat  BOWLING_Tests_Inns  \
# 12                  1.0                1.0                 NaN
# 41                  NaN                NaN                 NaN
# 56                  NaN                NaN                 NaN
# 69                  NaN                NaN                 NaN
# 126                 NaN                NaN                 NaN
# ...                 ...                ...                 ...
# 90263              31.0               87.0                56.0
# 90271               NaN                NaN                 NaN
# 90288              24.0               71.0                69.0
# 90291               NaN                NaN                 NaN
# 90298               NaN                NaN                 NaN
#
#       BOWLING_Tests_Balls  BOWLING_Tests_Runs  BOWLING_Tests_Wkts  \
# 12                    NaN                 NaN                 NaN
# 41                    NaN                 NaN                 NaN
# 56                    NaN                 NaN                 NaN
# 69                    NaN                 NaN                 NaN
# 126                   NaN                 NaN                 NaN
# ...                   ...                 ...                 ...
# 90263              2022.0              1163.0                23.0
# 90271                 NaN                 NaN                 NaN
# 90288              4392.0              2445.0                41.0
# 90291                 NaN                 NaN                 NaN
# 90298                 NaN                 NaN                 NaN
#
#        BOWLING_Tests_Ave BOWLING_Tests_Econ BOWLING_Tests_SR  \
# 12                   NaN                NaN              NaN
# 41                   NaN                NaN              NaN
# 56                   NaN                NaN              NaN
# 69                   NaN                NaN              NaN
# 126                  NaN                NaN              NaN
# ...                  ...                ...              ...
# 90263              50.56               3.45             87.9
# 90271                NaN                NaN              NaN
# 90288              59.63               3.34            107.1
# 90291                NaN                NaN              NaN
# 90298                NaN                NaN              NaN
#
#        BOWLING_Tests_5w  BOWLING_Tests_10
# 12                  NaN               NaN
# 41                  NaN               NaN
# 56                  NaN               NaN
# 69                  NaN               NaN
# 126                 NaN               NaN
# ...                 ...               ...
# 90263               0.0               0.0
# 90271               NaN               NaN
# 90288               0.0               0.0
# 90291               NaN               NaN
# 90298               NaN               NaN
#
# [3719 rows x 24 columns]

# %%
allrounder_players=players[(players['Playing role']=='Allrounder') & (players['BATTING_Tests_Inns'].notna()) & (players['BATTING_Tests_Mat']>10) ]
allrounder_players.shape
# Out:
# (53, 24)

# %%
allrounder_players.head()
# Out:
#            ID              NAME     COUNTRY Playing role   Batting style  \
# 12758   55973  Mohammad Rafique  Bangladesh   Allrounder   Left-hand bat
# 12846  629063      Mehidy Hasan  Bangladesh   Allrounder  Right-hand bat
# 12928   56025       Mahmudullah  Bangladesh   Allrounder  Right-hand bat
# 13038  300618     Nasir Hossain  Bangladesh   Allrounder  Right-hand bat
# 13378   56143   Shakib Al Hasan  Bangladesh   Allrounder   Left-hand bat
#
#                 Bowling style  BATTING_Tests_Mat  BATTING_Tests_Inns  \
# 12758  Slow left-arm orthodox               33.0                63.0
# 12846      Right-arm offbreak               19.0                36.0
# 12928      Right-arm offbreak               45.0                85.0
# 13038      Right-arm offbreak               19.0                32.0
# 13378  Slow left-arm orthodox               55.0               103.0
#
#        BATTING_Tests_NO  BATTING_Tests_Runs  BATTING_Tests_Ave  \
# 12758               6.0              1059.0              18.57
# 12846               6.0               554.0              18.46
# 12928               5.0              2655.0              33.18
# 13038               2.0              1044.0              34.80
# 13378               7.0              3807.0              39.65
#
#        BATTING_Tests_SR  BATTING_Tests_100  BATTING_Tests_50  \
# 12758             64.96                1.0               4.0
# 12846             51.20                0.0               2.0
# 12928             53.44                4.0              16.0
# 13038             54.46                1.0               6.0
# 13378             61.90                5.0              24.0
#
#        BOWLING_Tests_Mat  BOWLING_Tests_Inns BOWLING_Tests_Balls  \
# 12758               33.0                48.0              8744.0
# 12846               19.0                34.0              4903.0
# 12928               45.0                62.0              3345.0
# 13038               19.0                25.0               924.0
# 13378               55.0                93.0             12774.0
#
#        BOWLING_Tests_Runs  BOWLING_Tests_Wkts  BOWLING_Tests_Ave  \
# 12758              4076.0               100.0              40.76
# 12846              2748.0                86.0              31.95
# 12928              1910.0                42.0              45.47
# 13038               442.0                 8.0              55.25
# 13378              6415.0               205.0              31.29
#
#       BOWLING_Tests_Econ BOWLING_Tests_SR  BOWLING_Tests_5w  BOWLING_Tests_10
# 12758               2.79             87.4               7.0               0.0
# 12846               3.36             57.0               7.0               2.0
# 12928               3.42             79.6               1.0               0.0
# 13038               2.87            115.5               0.0               0.0
# 13378               3.01             62.3              18.0               2.0

# %%
# allrounder_players.hist(bins=90,figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'BATTING_Tests_Mat'}>,
#         <Axes: title={'center': 'BATTING_Tests_Inns'}>,
#         <Axes: title={'center': 'BATTING_Tests_NO'}>,
#         <Axes: title={'center': 'BATTING_Tests_Runs'}>],
#        [<Axes: title={'center': 'BATTING_Tests_Ave'}>,
#         <Axes: title={'center': 'BATTING_Tests_SR'}>,
#         <Axes: title={'center': 'BATTING_Tests_100'}>,
#         <Axes: title={'center': 'BATTING_Tests_50'}>],
#        [<Axes: title={'center': 'BOWLING_Tests_Mat'}>,
#         <Axes: title={'center': 'BOWLING_Tests_Inns'}>,
#         <Axes: title={'center': 'BOWLING_Tests_Runs'}>,
#         <Axes: title={'center': 'BOWLING_Tests_Wkts'}>],
#        [<Axes: title={'center': 'BOWLING_Tests_Ave'}>,
#         <Axes: title={'center': 'BOWLING_Tests_5w'}>,
#         <Axes: title={'center': 'BOWLING_Tests_10'}>, <Axes: >]],
#       dtype=object)

# %%
players.dtypes
# Out:
# ID                      object
# NAME                    object
# COUNTRY                 object
# Playing role            object
# Batting style           object
# Bowling style           object
# BATTING_Tests_Mat      float64
# BATTING_Tests_Inns     float64
# BATTING_Tests_NO       float64
# BATTING_Tests_Runs     float64
# BATTING_Tests_Ave      float64
# BATTING_Tests_SR       float64
# BATTING_Tests_100      float64
# BATTING_Tests_50       float64
# BOWLING_Tests_Mat      float64
# BOWLING_Tests_Inns     float64
# BOWLING_Tests_Balls     object
# BOWLING_Tests_Runs     float64
# BOWLING_Tests_Wkts     float64
# BOWLING_Tests_Ave      float64
# BOWLING_Tests_Econ      object
# BOWLING_Tests_SR        object
# BOWLING_Tests_5w       float64
# BOWLING_Tests_10       float64
# dtype: object

# %%
# pd.to_numeric(players['BOWLING_Tests_Balls'])

# %%
players.iloc[30916]
# Out:
# ID                                      54044
# NAME                             Diana Edulji
# COUNTRY                                 India
# Playing role                              NaN
# Batting style                  Right-hand bat
# Bowling style          Slow left-arm orthodox
# BATTING_Tests_Mat                        20.0
# BATTING_Tests_Inns                       30.0
# BATTING_Tests_NO                          5.0
# BATTING_Tests_Runs                      404.0
# BATTING_Tests_Ave                       16.16
# BATTING_Tests_SR                          NaN
# BATTING_Tests_100                         0.0
# BATTING_Tests_50                          1.0
# BOWLING_Tests_Mat                        20.0
# BOWLING_Tests_Inns                       35.0
# BOWLING_Tests_Balls                     5098+
# BOWLING_Tests_Runs                     1624.0
# BOWLING_Tests_Wkts                       63.0
# BOWLING_Tests_Ave                       25.77
# BOWLING_Tests_Econ                      1.85*
# BOWLING_Tests_SR                        83.5*
# BOWLING_Tests_5w                          1.0
# BOWLING_Tests_10                          0.0
# Name: 30916, dtype: object

# %%
players['BOWLING_Tests_Balls']=players['BOWLING_Tests_Balls'].str.replace(r'\W+', '', regex=True)

players['BOWLING_Tests_Balls']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 90304    NaN
# 90305    NaN
# 90306    NaN
# 90307    NaN
# 90308    NaN
# Name: BOWLING_Tests_Balls, Length: 90309, dtype: object

# %%
players.iloc[30916]
# Out:
# ID                                      54044
# NAME                             Diana Edulji
# COUNTRY                                 India
# Playing role                              NaN
# Batting style                  Right-hand bat
# Bowling style          Slow left-arm orthodox
# BATTING_Tests_Mat                        20.0
# BATTING_Tests_Inns                       30.0
# BATTING_Tests_NO                          5.0
# BATTING_Tests_Runs                      404.0
# BATTING_Tests_Ave                       16.16
# BATTING_Tests_SR                          NaN
# BATTING_Tests_100                         0.0
# BATTING_Tests_50                          1.0
# BOWLING_Tests_Mat                        20.0
# BOWLING_Tests_Inns                       35.0
# BOWLING_Tests_Balls                      5098
# BOWLING_Tests_Runs                     1624.0
# BOWLING_Tests_Wkts                       63.0
# BOWLING_Tests_Ave                       25.77
# BOWLING_Tests_Econ                      1.85*
# BOWLING_Tests_SR                        83.5*
# BOWLING_Tests_5w                          1.0
# BOWLING_Tests_10                          0.0
# Name: 30916, dtype: object

# %%
pd.to_numeric(players['BOWLING_Tests_Balls'])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 90304   NaN
# 90305   NaN
# 90306   NaN
# 90307   NaN
# 90308   NaN
# Name: BOWLING_Tests_Balls, Length: 90309, dtype: float64

# %%
pd.to_numeric(players['BOWLING_Tests_Balls'])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 90304   NaN
# 90305   NaN
# 90306   NaN
# 90307   NaN
# 90308   NaN
# Name: BOWLING_Tests_Balls, Length: 90309, dtype: float64

# %%
# allrounder_players.hist(bins=60,figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'BATTING_Tests_Mat'}>,
#         <Axes: title={'center': 'BATTING_Tests_Inns'}>,
#         <Axes: title={'center': 'BATTING_Tests_NO'}>,
#         <Axes: title={'center': 'BATTING_Tests_Runs'}>],
#        [<Axes: title={'center': 'BATTING_Tests_Ave'}>,
#         <Axes: title={'center': 'BATTING_Tests_SR'}>,
#         <Axes: title={'center': 'BATTING_Tests_100'}>,
#         <Axes: title={'center': 'BATTING_Tests_50'}>],
#        [<Axes: title={'center': 'BOWLING_Tests_Mat'}>,
#         <Axes: title={'center': 'BOWLING_Tests_Inns'}>,
#         <Axes: title={'center': 'BOWLING_Tests_Runs'}>,
#         <Axes: title={'center': 'BOWLING_Tests_Wkts'}>],
#        [<Axes: title={'center': 'BOWLING_Tests_Ave'}>,
#         <Axes: title={'center': 'BOWLING_Tests_5w'}>,
#         <Axes: title={'center': 'BOWLING_Tests_10'}>, <Axes: >]],
#       dtype=object)

# %%
players.dtypes
# Out:
# ID                      object
# NAME                    object
# COUNTRY                 object
# Playing role            object
# Batting style           object
# Bowling style           object
# BATTING_Tests_Mat      float64
# BATTING_Tests_Inns     float64
# BATTING_Tests_NO       float64
# BATTING_Tests_Runs     float64
# BATTING_Tests_Ave      float64
# BATTING_Tests_SR       float64
# BATTING_Tests_100      float64
# BATTING_Tests_50       float64
# BOWLING_Tests_Mat      float64
# BOWLING_Tests_Inns     float64
# BOWLING_Tests_Balls     object
# BOWLING_Tests_Runs     float64
# BOWLING_Tests_Wkts     float64
# BOWLING_Tests_Ave      float64
# BOWLING_Tests_Econ      object
# BOWLING_Tests_SR        object
# BOWLING_Tests_5w       float64
# BOWLING_Tests_10       float64
# dtype: object

# %%
import re

players = players.map(lambda x: re.sub(r'[^a-zA-Z0-9\s]', '', x) if isinstance(x, str) else x)

# %%
players.dtypes
# Out:
# ID                      object
# NAME                    object
# COUNTRY                 object
# Playing role            object
# Batting style           object
# Bowling style           object
# BATTING_Tests_Mat      float64
# BATTING_Tests_Inns     float64
# BATTING_Tests_NO       float64
# BATTING_Tests_Runs     float64
# BATTING_Tests_Ave      float64
# BATTING_Tests_SR       float64
# BATTING_Tests_100      float64
# BATTING_Tests_50       float64
# BOWLING_Tests_Mat      float64
# BOWLING_Tests_Inns     float64
# BOWLING_Tests_Balls     object
# BOWLING_Tests_Runs     float64
# BOWLING_Tests_Wkts     float64
# BOWLING_Tests_Ave      float64
# BOWLING_Tests_Econ      object
# BOWLING_Tests_SR        object
# BOWLING_Tests_5w       float64
# BOWLING_Tests_10       float64
# dtype: object

# %%
players['BOWLING_Tests_Balls'] = pd.to_numeric(players['BOWLING_Tests_Balls'])

# %%
players.dtypes
# Out:
# ID                      object
# NAME                    object
# COUNTRY                 object
# Playing role            object
# Batting style           object
# Bowling style           object
# BATTING_Tests_Mat      float64
# BATTING_Tests_Inns     float64
# BATTING_Tests_NO       float64
# BATTING_Tests_Runs     float64
# BATTING_Tests_Ave      float64
# BATTING_Tests_SR       float64
# BATTING_Tests_100      float64
# BATTING_Tests_50       float64
# BOWLING_Tests_Mat      float64
# BOWLING_Tests_Inns     float64
# BOWLING_Tests_Balls    float64
# BOWLING_Tests_Runs     float64
# BOWLING_Tests_Wkts     float64
# BOWLING_Tests_Ave      float64
# BOWLING_Tests_Econ      object
# BOWLING_Tests_SR        object
# BOWLING_Tests_5w       float64
# BOWLING_Tests_10       float64
# dtype: object

# %%
players['BOWLING_Tests_SR']=pd.to_numeric(players['BOWLING_Tests_SR'])

# %%
players.dtypes
# Out:
# ID                      object
# NAME                    object
# COUNTRY                 object
# Playing role            object
# Batting style           object
# Bowling style           object
# BATTING_Tests_Mat      float64
# BATTING_Tests_Inns     float64
# BATTING_Tests_NO       float64
# BATTING_Tests_Runs     float64
# BATTING_Tests_Ave      float64
# BATTING_Tests_SR       float64
# BATTING_Tests_100      float64
# BATTING_Tests_50       float64
# BOWLING_Tests_Mat      float64
# BOWLING_Tests_Inns     float64
# BOWLING_Tests_Balls    float64
# BOWLING_Tests_Runs     float64
# BOWLING_Tests_Wkts     float64
# BOWLING_Tests_Ave      float64
# BOWLING_Tests_Econ      object
# BOWLING_Tests_SR       float64
# BOWLING_Tests_5w       float64
# BOWLING_Tests_10       float64
# dtype: object

# %%
players['BOWLING_Tests_Econ'] = pd.to_numeric(players['BOWLING_Tests_Econ'])

# %%
players.dtypes
# Out:
# ID                      object
# NAME                    object
# COUNTRY                 object
# Playing role            object
# Batting style           object
# Bowling style           object
# BATTING_Tests_Mat      float64
# BATTING_Tests_Inns     float64
# BATTING_Tests_NO       float64
# BATTING_Tests_Runs     float64
# BATTING_Tests_Ave      float64
# BATTING_Tests_SR       float64
# BATTING_Tests_100      float64
# BATTING_Tests_50       float64
# BOWLING_Tests_Mat      float64
# BOWLING_Tests_Inns     float64
# BOWLING_Tests_Balls    float64
# BOWLING_Tests_Runs     float64
# BOWLING_Tests_Wkts     float64
# BOWLING_Tests_Ave      float64
# BOWLING_Tests_Econ     float64
# BOWLING_Tests_SR       float64
# BOWLING_Tests_5w       float64
# BOWLING_Tests_10       float64
# dtype: object

# %%
# players.hist(bins=60,figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'BATTING_Tests_Mat'}>,
#         <Axes: title={'center': 'BATTING_Tests_Inns'}>,
#         <Axes: title={'center': 'BATTING_Tests_NO'}>,
#         <Axes: title={'center': 'BATTING_Tests_Runs'}>],
#        [<Axes: title={'center': 'BATTING_Tests_Ave'}>,
#         <Axes: title={'center': 'BATTING_Tests_SR'}>,
#         <Axes: title={'center': 'BATTING_Tests_100'}>,
#         <Axes: title={'center': 'BATTING_Tests_50'}>],
#        [<Axes: title={'center': 'BOWLING_Tests_Mat'}>,
#         <Axes: title={'center': 'BOWLING_Tests_Inns'}>,
#         <Axes: title={'center': 'BOWLING_Tests_Balls'}>,
#         <Axes: title={'center': 'BOWLING_Tests_Runs'}>],
#        [<Axes: title={'center': 'BOWLING_Tests_Wkts'}>,
#         <Axes: title={'center': 'BOWLING_Tests_Ave'}>,
#         <Axes: title={'center': 'BOWLING_Tests_Econ'}>,
#         <Axes: title={'center': 'BOWLING_Tests_SR'}>],
#        [<Axes: title={'center': 'BOWLING_Tests_5w'}>,
#         <Axes: title={'center': 'BOWLING_Tests_10'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
players.columns
# Out:
# Index(['ID', 'NAME', 'COUNTRY', 'Playing role', 'Batting style',
#        'Bowling style', 'BATTING_Tests_Mat', 'BATTING_Tests_Inns',
#        'BATTING_Tests_NO', 'BATTING_Tests_Runs', 'BATTING_Tests_Ave',
#        'BATTING_Tests_SR', 'BATTING_Tests_100', 'BATTING_Tests_50',
#        'BOWLING_Tests_Mat', 'BOWLING_Tests_Inns', 'BOWLING_Tests_Balls',
#        'BOWLING_Tests_Runs', 'BOWLING_Tests_Wkts', 'BOWLING_Tests_Ave',
#        'BOWLING_Tests_Econ', 'BOWLING_Tests_SR', 'BOWLING_Tests_5w',
#        'BOWLING_Tests_10'],
#       dtype='object')

# %%
players=players[['ID', 'NAME', 'COUNTRY', 'Playing role', 'Batting style',
       'Bowling style', 'BATTING_Tests_Mat', 'BATTING_Tests_Inns', 'BATTING_Tests_Runs', 'BATTING_Tests_Ave',
       'BATTING_Tests_SR', 'BATTING_Tests_100', 'BATTING_Tests_50',
       'BOWLING_Tests_Mat', 'BOWLING_Tests_Inns', 'BOWLING_Tests_Balls',
       'BOWLING_Tests_Wkts', 'BOWLING_Tests_Ave',
       'BOWLING_Tests_Econ', 'BOWLING_Tests_SR', 'BOWLING_Tests_5w',
       'BOWLING_Tests_10']]

# %%
players
# Out:
#            ID                 NAME  COUNTRY Playing role  Batting style  \
# 0        8772         Henry Arkell  England          NaN  Righthand bat
# 1      532565        Richard Nyren  England          NaN   Lefthand bat
# 2       16856     Sydney Maartensz  England          NaN  Righthand bat
# 3       16715         Brian Lander  England          NaN  Righthand bat
# 4       15989     Derek Kenderdine  England          NaN  Righthand bat
# ...       ...                  ...      ...          ...            ...
# 90304   19777       Keith Robinson  England          NaN            NaN
# 90305   14843  Trevitt HineHaycock  England          NaN  Righthand bat
# 90306   15025          John Hughes  England          NaN  Righthand bat
# 90307   11167         John Clayton  England          NaN  Righthand bat
# 90308  565677            H Clewitt  England          NaN            NaN
#
#                  Bowling style  BATTING_Tests_Mat  BATTING_Tests_Inns  \
# 0                          NaN                NaN                 NaN
# 1      Leftarm bowler underarm                NaN                 NaN
# 2                          NaN                NaN                 NaN
# 3              Rightarm medium                NaN                 NaN
# 4          Rightarm mediumfast                NaN                 NaN
# ...                        ...                ...                 ...
# 90304                      NaN                NaN                 NaN
# 90305                      NaN                NaN                 NaN
# 90306   Rightarm slow roundarm                NaN                 NaN
# 90307      Rightarm fastmedium                NaN                 NaN
# 90308                      NaN                NaN                 NaN
#
#        BATTING_Tests_Runs  BATTING_Tests_Ave  BATTING_Tests_SR  \
# 0                     NaN                NaN               NaN
# 1                     NaN                NaN               NaN
# 2                     NaN                NaN               NaN
# 3                     NaN                NaN               NaN
# 4                     NaN                NaN               NaN
# ...                   ...                ...               ...
# 90304                 NaN                NaN               NaN
# 90305                 NaN                NaN               NaN
# 90306                 NaN                NaN               NaN
# 90307                 NaN                NaN               NaN
# 90308                 NaN                NaN               NaN
#
#        BATTING_Tests_100  BATTING_Tests_50  BOWLING_Tests_Mat  \
# 0                    NaN               NaN                NaN
# 1                    NaN               NaN                NaN
# 2                    NaN               NaN                NaN
# 3                    NaN               NaN                NaN
# 4                    NaN               NaN                NaN
# ...                  ...               ...                ...
# 90304                NaN               NaN                NaN
# 90305                NaN               NaN                NaN
# 90306                NaN               NaN                NaN
# 90307                NaN               NaN                NaN
# 90308                NaN               NaN                NaN
#
#        BOWLING_Tests_Inns  BOWLING_Tests_Balls  BOWLING_Tests_Wkts  \
# 0                     NaN                  NaN                 NaN
# 1                     NaN                  NaN                 NaN
# 2                     NaN                  NaN                 NaN
# 3                     NaN                  NaN                 NaN
# 4                     NaN                  NaN                 NaN
# ...                   ...                  ...                 ...
# 90304                 NaN                  NaN                 NaN
# 90305                 NaN                  NaN                 NaN
# 90306                 NaN                  NaN                 NaN
# 90307                 NaN                  NaN                 NaN
# 90308                 NaN                  NaN                 NaN
#
#        BOWLING_Tests_Ave  BOWLING_Tests_Econ  BOWLING_Tests_SR  \
# 0                    NaN                 NaN               NaN
# 1                    NaN                 NaN               NaN
# 2                    NaN                 NaN               NaN
# 3                    NaN                 NaN               NaN
# 4                    NaN                 NaN               NaN
# ...                  ...                 ...               ...
# 90304                NaN                 NaN               NaN
# 90305                NaN                 NaN               NaN
# 90306                NaN                 NaN               NaN
# 90307                NaN                 NaN               NaN
# 90308                NaN                 NaN               NaN
#
#        BOWLING_Tests_5w  BOWLING_Tests_10
# 0                   NaN               NaN
# 1                   NaN               NaN
# 2                   NaN               NaN
# 3                   NaN               NaN
# 4                   NaN               NaN
# ...                 ...               ...
# 90304               NaN               NaN
# 90305               NaN               NaN
# 90306               NaN               NaN
# 90307               NaN               NaN
# 90308               NaN               NaN
#
# [90309 rows x 22 columns]

# %%
# pd.to_numeric(players['ID'])

# %%
players['Playing role'].value_counts()
# Out:
# Playing role
# Bowler                       1083
# Allrounder                    735
# Batsman                       369
# Wicketkeeper                  328
# Opening batsman               321
# Middleorder batsman           297
# Wicketkeeper batsman          261
# Toporder batsman              236
# Batting allrounder             35
# Bowling allrounder             34
# 12th man                       17
# Batsman Batsman                 1
# 1                               1
# Wicketkeeper Wicketkeeper       1
# Name: count, dtype: int64

# %%
players['ID'].iloc[69909]
# Out:
# 'to the spot where he had hit his first four for Rugby v Marlborough in 1889 It was my very great privilege to be present on a most impressive occasion The wind blew hard during the ceremony'

# %%
players.shape
# Out:
# (90309, 22)

# %%
import re

# Extract first numeric value from each entry
players['ID_clean'] = players['ID'].apply(lambda x: re.findall(r'\d+\.?\d*', str(x)))

# Convert to float (or int) if a number was found
players['ID_clean'] = players['ID_clean'].apply(lambda x: float(x[0]) if x else None)

# %%
players.dtypes
# Out:
# ID                      object
# NAME                    object
# COUNTRY                 object
# Playing role            object
# Batting style           object
# Bowling style           object
# BATTING_Tests_Mat      float64
# BATTING_Tests_Inns     float64
# BATTING_Tests_Runs     float64
# BATTING_Tests_Ave      float64
# BATTING_Tests_SR       float64
# BATTING_Tests_100      float64
# BATTING_Tests_50       float64
# BOWLING_Tests_Mat      float64
# BOWLING_Tests_Inns     float64
# BOWLING_Tests_Balls    float64
# BOWLING_Tests_Wkts     float64
# BOWLING_Tests_Ave      float64
# BOWLING_Tests_Econ     float64
# BOWLING_Tests_SR       float64
# BOWLING_Tests_5w       float64
# BOWLING_Tests_10       float64
# ID_clean               float64
# dtype: object

# %%
players.columns
# Out:
# Index(['ID', 'NAME', 'COUNTRY', 'Playing role', 'Batting style',
#        'Bowling style', 'BATTING_Tests_Mat', 'BATTING_Tests_Inns',
#        'BATTING_Tests_Runs', 'BATTING_Tests_Ave', 'BATTING_Tests_SR',
#        'BATTING_Tests_100', 'BATTING_Tests_50', 'BOWLING_Tests_Mat',
#        'BOWLING_Tests_Inns', 'BOWLING_Tests_Balls', 'BOWLING_Tests_Wkts',
#        'BOWLING_Tests_Ave', 'BOWLING_Tests_Econ', 'BOWLING_Tests_SR',
#        'BOWLING_Tests_5w', 'BOWLING_Tests_10', 'ID_clean'],
#       dtype='object')

# %%
players=players[['ID_clean', 'Playing role', 'BATTING_Tests_Mat', 'BATTING_Tests_Inns',
       'BATTING_Tests_Runs', 'BATTING_Tests_Ave', 'BATTING_Tests_SR',
       'BATTING_Tests_100', 'BATTING_Tests_50', 'BOWLING_Tests_Mat',
       'BOWLING_Tests_Inns', 'BOWLING_Tests_Balls', 'BOWLING_Tests_Wkts',
       'BOWLING_Tests_Ave', 'BOWLING_Tests_Econ', 'BOWLING_Tests_SR',
       'BOWLING_Tests_5w', 'BOWLING_Tests_10']]

# %%
players.shape
# Out:
# (90309, 18)

# %%
players.dtypes
# Out:
# ID_clean               float64
# Playing role            object
# BATTING_Tests_Mat      float64
# BATTING_Tests_Inns     float64
# BATTING_Tests_Runs     float64
# BATTING_Tests_Ave      float64
# BATTING_Tests_SR       float64
# BATTING_Tests_100      float64
# BATTING_Tests_50       float64
# BOWLING_Tests_Mat      float64
# BOWLING_Tests_Inns     float64
# BOWLING_Tests_Balls    float64
# BOWLING_Tests_Wkts     float64
# BOWLING_Tests_Ave      float64
# BOWLING_Tests_Econ     float64
# BOWLING_Tests_SR       float64
# BOWLING_Tests_5w       float64
# BOWLING_Tests_10       float64
# dtype: object

# %%
players.columns
# Out:
# Index(['ID_clean', 'Playing role', 'BATTING_Tests_Mat', 'BATTING_Tests_Inns',
#        'BATTING_Tests_Runs', 'BATTING_Tests_Ave', 'BATTING_Tests_SR',
#        'BATTING_Tests_100', 'BATTING_Tests_50', 'BOWLING_Tests_Mat',
#        'BOWLING_Tests_Inns', 'BOWLING_Tests_Balls', 'BOWLING_Tests_Wkts',
#        'BOWLING_Tests_Ave', 'BOWLING_Tests_Econ', 'BOWLING_Tests_SR',
#        'BOWLING_Tests_5w', 'BOWLING_Tests_10'],
#       dtype='object')

# %%
# players.hist(bins=60,figsize=(20,20))

# %%
players.shape
# Out:
# (90309, 18)

# %%
players.columns
# Out:
# Index(['ID_clean', 'Playing role', 'BATTING_Tests_Mat', 'BATTING_Tests_Inns',
#        'BATTING_Tests_Runs', 'BATTING_Tests_Ave', 'BATTING_Tests_SR',
#        'BATTING_Tests_100', 'BATTING_Tests_50', 'BOWLING_Tests_Mat',
#        'BOWLING_Tests_Inns', 'BOWLING_Tests_Balls', 'BOWLING_Tests_Wkts',
#        'BOWLING_Tests_Ave', 'BOWLING_Tests_Econ', 'BOWLING_Tests_SR',
#        'BOWLING_Tests_5w', 'BOWLING_Tests_10'],
#       dtype='object')

# %%
players
# Out:
#        ID_clean Playing role  BATTING_Tests_Mat  BATTING_Tests_Inns  \
# 0        8772.0          NaN                NaN                 NaN
# 1      532565.0          NaN                NaN                 NaN
# 2       16856.0          NaN                NaN                 NaN
# 3       16715.0          NaN                NaN                 NaN
# 4       15989.0          NaN                NaN                 NaN
# ...         ...          ...                ...                 ...
# 90304   19777.0          NaN                NaN                 NaN
# 90305   14843.0          NaN                NaN                 NaN
# 90306   15025.0          NaN                NaN                 NaN
# 90307   11167.0          NaN                NaN                 NaN
# 90308  565677.0          NaN                NaN                 NaN
#
#        BATTING_Tests_Runs  BATTING_Tests_Ave  BATTING_Tests_SR  \
# 0                     NaN                NaN               NaN
# 1                     NaN                NaN               NaN
# 2                     NaN                NaN               NaN
# 3                     NaN                NaN               NaN
# 4                     NaN                NaN               NaN
# ...                   ...                ...               ...
# 90304                 NaN                NaN               NaN
# 90305                 NaN                NaN               NaN
# 90306                 NaN                NaN               NaN
# 90307                 NaN                NaN               NaN
# 90308                 NaN                NaN               NaN
#
#        BATTING_Tests_100  BATTING_Tests_50  BOWLING_Tests_Mat  \
# 0                    NaN               NaN                NaN
# 1                    NaN               NaN                NaN
# 2                    NaN               NaN                NaN
# 3                    NaN               NaN                NaN
# 4                    NaN               NaN                NaN
# ...                  ...               ...                ...
# 90304                NaN               NaN                NaN
# 90305                NaN               NaN                NaN
# 90306                NaN               NaN                NaN
# 90307                NaN               NaN                NaN
# 90308                NaN               NaN                NaN
#
#        BOWLING_Tests_Inns  BOWLING_Tests_Balls  BOWLING_Tests_Wkts  \
# 0                     NaN                  NaN                 NaN
# 1                     NaN                  NaN                 NaN
# 2                     NaN                  NaN                 NaN
# 3                     NaN                  NaN                 NaN
# 4                     NaN                  NaN                 NaN
# ...                   ...                  ...                 ...
# 90304                 NaN                  NaN                 NaN
# 90305                 NaN                  NaN                 NaN
# 90306                 NaN                  NaN                 NaN
# 90307                 NaN                  NaN                 NaN
# 90308                 NaN                  NaN                 NaN
#
#        BOWLING_Tests_Ave  BOWLING_Tests_Econ  BOWLING_Tests_SR  \
# 0                    NaN                 NaN               NaN
# 1                    NaN                 NaN               NaN
# 2                    NaN                 NaN               NaN
# 3                    NaN                 NaN               NaN
# 4                    NaN                 NaN               NaN
# ...                  ...                 ...               ...
# 90304                NaN                 NaN               NaN
# 90305                NaN                 NaN               NaN
# 90306                NaN                 NaN               NaN
# 90307                NaN                 NaN               NaN
# 90308                NaN                 NaN               NaN
#
#        BOWLING_Tests_5w  BOWLING_Tests_10
# 0                   NaN               NaN
# 1                   NaN               NaN
# 2                   NaN               NaN
# 3                   NaN               NaN
# 4                   NaN               NaN
# ...                 ...               ...
# 90304               NaN               NaN
# 90305               NaN               NaN
# 90306               NaN               NaN
# 90307               NaN               NaN
# 90308               NaN               NaN
#
# [90309 rows x 18 columns]

# %%
# players = players[players['BATTING_Tests_Mat']==87]

# %%
players = players[players['Playing role'].notna()]
players
# Out:
#         ID_clean          Playing role  BATTING_Tests_Mat  BATTING_Tests_Inns  \
# 12       43860.0  Wicketkeeper batsman                1.0                 2.0
# 41      318615.0               Batsman                NaN                 NaN
# 56     1159659.0          Wicketkeeper                NaN                 NaN
# 69     1107677.0            Allrounder                NaN                 NaN
# 126    1013221.0  Wicketkeeper batsman                NaN                 NaN
# ...          ...                   ...                ...                 ...
# 90263    52969.0               Batsman               87.0               154.0
# 90271   314622.0                Bowler                NaN                 NaN
# 90288    52983.0      Toporder batsman               71.0               127.0
# 90291   252954.0               Batsman                NaN                 NaN
# 90298   333056.0            Allrounder                NaN                 NaN
#
#        BATTING_Tests_Runs  BATTING_Tests_Ave  BATTING_Tests_SR  \
# 12                   88.0              44.00             43.78
# 41                    NaN                NaN               NaN
# 56                    NaN                NaN               NaN
# 69                    NaN                NaN               NaN
# 126                   NaN                NaN               NaN
# ...                   ...                ...               ...
# 90263              5842.0              40.01             46.79
# 90271                 NaN                NaN               NaN
# 90288              3917.0              32.64             47.65
# 90291                 NaN                NaN               NaN
# 90298                 NaN                NaN               NaN
#
#        BATTING_Tests_100  BATTING_Tests_50  BOWLING_Tests_Mat  \
# 12                   0.0               1.0                1.0
# 41                   NaN               NaN                NaN
# 56                   NaN               NaN                NaN
# 69                   NaN               NaN                NaN
# 126                  NaN               NaN                NaN
# ...                  ...               ...                ...
# 90263               15.0              31.0               87.0
# 90271                NaN               NaN                NaN
# 90288                7.0              24.0               71.0
# 90291                NaN               NaN                NaN
# 90298                NaN               NaN                NaN
#
#        BOWLING_Tests_Inns  BOWLING_Tests_Balls  BOWLING_Tests_Wkts  \
# 12                    NaN                  NaN                 NaN
# 41                    NaN                  NaN                 NaN
# 56                    NaN                  NaN                 NaN
# 69                    NaN                  NaN                 NaN
# 126                   NaN                  NaN                 NaN
# ...                   ...                  ...                 ...
# 90263                56.0                  NaN                23.0
# 90271                 NaN                  NaN                 NaN
# 90288                69.0                  NaN                41.0
# 90291                 NaN                  NaN                 NaN
# 90298                 NaN                  NaN                 NaN
#
#        BOWLING_Tests_Ave  BOWLING_Tests_Econ  BOWLING_Tests_SR  \
# 12                   NaN                 NaN               NaN
# 41                   NaN                 NaN               NaN
# 56                   NaN                 NaN               NaN
# 69                   NaN                 NaN               NaN
# 126                  NaN                 NaN               NaN
# ...                  ...                 ...               ...
# 90263              50.56                3.45              87.9
# 90271                NaN                 NaN               NaN
# 90288              59.63                3.34             107.1
# 90291                NaN                 NaN               NaN
# 90298                NaN                 NaN               NaN
#
#        BOWLING_Tests_5w  BOWLING_Tests_10
# 12                  NaN               NaN
# 41                  NaN               NaN
# 56                  NaN               NaN
# 69                  NaN               NaN
# 126                 NaN               NaN
# ...                 ...               ...
# 90263               0.0               0.0
# 90271               NaN               NaN
# 90288               0.0               0.0
# 90291               NaN               NaN
# 90298               NaN               NaN
#
# [3719 rows x 18 columns]

# %%
X_players = players[['ID_clean','BATTING_Tests_Mat', 'BATTING_Tests_Inns',
       'BATTING_Tests_Runs', 'BATTING_Tests_Ave', 'BATTING_Tests_SR',
       'BATTING_Tests_100', 'BATTING_Tests_50', 'BOWLING_Tests_Mat',
       'BOWLING_Tests_Inns', 'BOWLING_Tests_Balls', 'BOWLING_Tests_Wkts',
       'BOWLING_Tests_Ave', 'BOWLING_Tests_Econ', 'BOWLING_Tests_SR',
       'BOWLING_Tests_5w', 'BOWLING_Tests_10']]
y_players = players[['Playing role']]

# %%
# X_test = players[players['Playing role']=='Allrounder']
# X_test
X_test = X_players[X_players['ID_clean']==53118.0]
X_test
# Out:
#        ID_clean  BATTING_Tests_Mat  BATTING_Tests_Inns  BATTING_Tests_Runs  \
# 90134   53118.0               10.0                14.0               320.0
#
#        BATTING_Tests_Ave  BATTING_Tests_SR  BATTING_Tests_100  \
# 90134              24.61             70.02                1.0
#
#        BATTING_Tests_50  BOWLING_Tests_Mat  BOWLING_Tests_Inns  \
# 90134               0.0               10.0                13.0
#
#        BOWLING_Tests_Balls  BOWLING_Tests_Wkts  BOWLING_Tests_Ave  \
# 90134                  NaN                 7.0              49.14
#
#        BOWLING_Tests_Econ  BOWLING_Tests_SR  BOWLING_Tests_5w  \
# 90134                3.17              93.0               0.0
#
#        BOWLING_Tests_10
# 90134               0.0

# %%
print(X_players.shape)
print(y_players.shape)
# Out:
# (3719, 17)
# (3719, 1)

# %%
# from sklearn.impute import SimpleImputer

# imputer = SimpleImputer(strategy='mean')  # or 'median', 'most_frequent'
# X_players = imputer.fit_transform(x_players)
# y_players = imputer.fit_transform(y_players)

# %%
X_players
# Out:
#        ID_clean  BATTING_Tests_Mat  BATTING_Tests_Inns  BATTING_Tests_Runs  \
# 0        8772.0                NaN                 NaN                 NaN
# 1      532565.0                NaN                 NaN                 NaN
# 2       16856.0                NaN                 NaN                 NaN
# 3       16715.0                NaN                 NaN                 NaN
# 4       15989.0                NaN                 NaN                 NaN
# ...         ...                ...                 ...                 ...
# 90304   19777.0                NaN                 NaN                 NaN
# 90305   14843.0                NaN                 NaN                 NaN
# 90306   15025.0                NaN                 NaN                 NaN
# 90307   11167.0                NaN                 NaN                 NaN
# 90308  565677.0                NaN                 NaN                 NaN
#
#        BATTING_Tests_Ave  BATTING_Tests_SR  BATTING_Tests_100  \
# 0                    NaN               NaN                NaN
# 1                    NaN               NaN                NaN
# 2                    NaN               NaN                NaN
# 3                    NaN               NaN                NaN
# 4                    NaN               NaN                NaN
# ...                  ...               ...                ...
# 90304                NaN               NaN                NaN
# 90305                NaN               NaN                NaN
# 90306                NaN               NaN                NaN
# 90307                NaN               NaN                NaN
# 90308                NaN               NaN                NaN
#
#        BATTING_Tests_50  BOWLING_Tests_Mat  BOWLING_Tests_Inns  \
# 0                   NaN                NaN                 NaN
# 1                   NaN                NaN                 NaN
# 2                   NaN                NaN                 NaN
# 3                   NaN                NaN                 NaN
# 4                   NaN                NaN                 NaN
# ...                 ...                ...                 ...
# 90304               NaN                NaN                 NaN
# 90305               NaN                NaN                 NaN
# 90306               NaN                NaN                 NaN
# 90307               NaN                NaN                 NaN
# 90308               NaN                NaN                 NaN
#
#        BOWLING_Tests_Balls  BOWLING_Tests_Wkts  BOWLING_Tests_Ave  \
# 0                      NaN                 NaN                NaN
# 1                      NaN                 NaN                NaN
# 2                      NaN                 NaN                NaN
# 3                      NaN                 NaN                NaN
# 4                      NaN                 NaN                NaN
# ...                    ...                 ...                ...
# 90304                  NaN                 NaN                NaN
# 90305                  NaN                 NaN                NaN
# 90306                  NaN                 NaN                NaN
# 90307                  NaN                 NaN                NaN
# 90308                  NaN                 NaN                NaN
#
#        BOWLING_Tests_Econ  BOWLING_Tests_SR  BOWLING_Tests_5w  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
# ...                   ...               ...               ...
# 90304                 NaN               NaN               NaN
# 90305                 NaN               NaN               NaN
# 90306                 NaN               NaN               NaN
# 90307                 NaN               NaN               NaN
# 90308                 NaN               NaN               NaN
#
#        BOWLING_Tests_10
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 90304               NaN
# 90305               NaN
# 90306               NaN
# 90307               NaN
# 90308               NaN
#
# [90309 rows x 17 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier().fit(X_players,y_players)

# %%
y_pred = clf.predict(X_players)
y_pred
# Out:
# array(['Wicketkeeper batsman', 'Batsman', 'Wicketkeeper', ...,
#        'Toporder batsman', 'Batsman', 'Allrounder'], dtype=object)

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array(['Allrounder'], dtype=object)
